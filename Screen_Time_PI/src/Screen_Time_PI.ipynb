# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeftav/Portfolio---analise_de_dados/blob/main/Screen_Time_PI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %% [markdown]
# Link: https://www.kaggle.com/datasets/muhammadalirazazaidi/screen-time-data-productivity-and-attention-span

# %% [markdown]
# # 📊 Informações principais do conjunto de dados
#
# - **Número de participantes:** 200 respondentes
# - **Objetivo:** Analisar os efeitos do tempo de tela na produtividade e na capacidade de atenção
#
# ---
#
# ## 👥 Informações demográficas coletadas
#
# - Idade
# - Gênero
# - Nível de escolaridade
# - Ocupação
#
# ---
#
# ## 📱 Padrões de uso de tela
#
# - Tempo diário de uso de telas
# - Principais dispositivos utilizados
# - Atividades realizadas durante o tempo de tela
#
# ---
#
# ## 🧠 Fatores comportamentais
#
# - Preferências de ambiente de trabalho
# - Nível percebido de produtividade
# - Duração da atenção/concentração
#
# ---
#
# ## 🔧 Estratégias e ferramentas
#
# - Estratégias para manter o foco
# - Manejo de notificações
# - Uso de ferramentas de monitoramento de tempo de tela
#
# ---
#
# ## 📈 Aplicações analíticas
#
# - Testes estatísticos como **qui-quadrado**, **estudos de correlação** e **testes de hipótese**
# - Identificação de padrões e relações entre comportamentos digitais e resultados de produtividade
#
# ---
#
# ## 💡 Finalidade
#
# Ideal para **pesquisadores** e **entusiastas de dados** interessados em compreender os padrões de consumo digital e suas implicações na vida cotidiana.

# %%
# 🧹 1. Importação e Leitura dos Dados
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Ajuste estético
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
url = 'https://drive.google.com/uc?export=download&id=1dhOAJrnJqQG9UeKhB88rhZYvXXskiHSV'
df = pd.read_csv(url, index_col=0)

# %%
# 🔎 2. Visualização geral dos dados
df.head(10)
# Out:
#       Age Group  Gender       Education Level    Occupation  \
# 0         18–24    Male         Undergraduate       Student
# 1         18–24    Male         Undergraduate  Professional
# 2  45 and above  Female              Graduate  Professional
# 3         25–34    Male         Undergraduate  Professional
# 4  45 and above    Male              Graduate  Professional
# 5      Below 18  Female  High school or below       Student
# 6         35–44    Male              Graduate  Professional
# 7         18–24  Female         Undergraduate       Student
# 8      Below 18    Male  High school or below       Student
# 9      Below 18    Male         Undergraduate       Student
#
#   Average Screen Time      Device  \
# 0        More than 10  Smartphone
# 1                8-10  Smartphone
# 2                 4–6  Smartphone
# 3                8-10   Laptop/PC
# 4                8-10   Laptop/PC
# 5                 4–6  Smartphone
# 6                8-10   Laptop/PC
# ...

# %%
# Informações gerais sobre o DataFrame
df.info()

# Estatísticas descritivas
df.describe()

# Verificar valores únicos em uma coluna específica
df['Gender'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age Group                   200 non-null    object
#  1   Gender                      200 non-null    object
#  2   Education Level             200 non-null    object
#  3   Occupation                  200 non-null    object
#  4   Average Screen Time         200 non-null    object
#  5   Device                      200 non-null    object
#  6   Screen Activity             200 non-null    object
#  7   App Category                200 non-null    object
#  8   Screen Time Period          200 non-null    object
#  9   Environment                 198 non-null    object
#  10  Productivity                200 non-null    object
#  11  Attention Span              200 non-null    object
#  12  Work Strategy               197 non-null    object
# ...

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Average Screen Time')
plt.title('Distribuição do Tempo Médio de Tela')
plt.show()

# %%
# Criar uma nova coluna com quebras de linha nos nomes longos
df['App Category Wrap'] = df['App Category'].apply(lambda x: '\n'.join(x.split(' ')))

# Plotar usando a nova coluna
sns.countplot(x='App Category Wrap', data=df)
plt.title('Por utilização')
plt.xticks(rotation=0)  # Agora pode deixar reto ou girar menos
plt.tight_layout()
plt.show()

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age Group                   200 non-null    object
#  1   Gender                      200 non-null    object
#  2   Education Level             200 non-null    object
#  3   Occupation                  200 non-null    object
#  4   Average Screen Time         200 non-null    object
#  5   Device                      200 non-null    object
#  6   Screen Activity             200 non-null    object
#  7   App Category                200 non-null    object
#  8   Screen Time Period          200 non-null    object
#  9   Environment                 198 non-null    object
#  10  Productivity                200 non-null    object
#  11  Attention Span              200 non-null    object
#  12  Work Strategy               197 non-null    object
# ...

# %%
print(df.describe(include='all').round(2).T)
# Out:
#                            count unique  \
# Age Group                    200      5
# Gender                       200      2
# Education Level              200      3
# Occupation                   200      2
# Average Screen Time          200      6
# Device                       200      4
# Screen Activity              200      2
# App Category                 200      5
# Screen Time Period           200      4
# Environment                  198      4
# Productivity                 200      3
# Attention Span               200      4
# Work Strategy                197      4
# Notification Handling        199      4
# Usage of Productivity Apps   200      3
# App Category Wrap            200      5
#
#                                                                           top  \
# Age Group                                                               18–24
# Gender                                                                   Male
# ...

# %%
# 📊 3. Análises de distribuição

# Distribuição por faixa etária
sns.countplot(x='Age Group', data=df, palette='viridis')
plt.title('Distribuição por Faixa Etária')
plt.show()
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\1181669737.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age Group', data=df, palette='viridis')

# %%
# Distribuição por Produtividade
sns.countplot(x='Productivity', data=df, palette='viridis')
plt.title('Distribuição por Produtividade')
plt.show()
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\3105997949.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Productivity', data=df, palette='viridis')

# %%
import textwrap

# Distribuição por Produtividade
sns.countplot(x='Productivity', data=df, palette='viridis')

# Definir o título
plt.title('Distribuição por Produtividade')

# Quebrar as legendas do eixo x
labels = plt.gca().get_xticklabels()
wrapped_labels = [textwrap.fill(label.get_text(), width=10) for label in labels]
plt.gca().set_xticklabels(wrapped_labels)

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\606490222.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Productivity', data=df, palette='viridis')
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\606490222.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(wrapped_labels)

# %%
# Distribuição por Escolaridade
sns.countplot(x='Education Level', data=df, palette='viridis')
plt.title('Distribuição por Escolaridade')
plt.show()
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\1508834487.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Education Level', data=df, palette='viridis')

# %%
# Distribuição por Ocupação
sns.countplot(x='Usage of Productivity Apps', data=df, palette='viridis')
plt.title('Uso de Apps de Produtividade')
plt.show()
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\1284717645.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Usage of Productivity Apps', data=df, palette='viridis')

# %%
# Distribuição por Ocupação
sns.countplot(x='Occupation', data=df, palette='viridis')
plt.title('Distribuição por Ocupação')
plt.show()
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\1494243587.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Occupation', data=df, palette='viridis')

# %%
# Gênero
sns.countplot(x='Gender', data=df, palette='Set2')
plt.title('Distribuição por Gênero')
plt.show()
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\3111867043.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='Set2')

# %%
# Tempo médio de tela por faixa etária
sns.boxplot(x='Age Group', y='Average Screen Time', data=df)
plt.title('Tempo Médio de Tela por Faixa Etária')
plt.show()

# %%
# 🔁 4. Conversões úteis
# Criando uma coluna numérica para tempo médio de tela
def converter_tempo(t):
    if t == '4–6':
        return 5
    elif t == '6–8':
        return 7
    elif t == '8-10':
        return 9
    elif t == 'More than 10':
        return 11
    else:
        return None

df['ScreenTimeNum'] = df['Average Screen Time'].apply(converter_tempo)

# %%
# 🎯 5. Correlações e agrupamentos
# Tempo médio por dispositivo
media_tempo_por_dispositivo = df.groupby('Device')['ScreenTimeNum'].mean().reset_index()
sns.barplot(data=media_tempo_por_dispositivo, x='Device', y='ScreenTimeNum', palette='coolwarm')
plt.title('Tempo Médio de Tela por Dispositivo')
plt.ylabel('Horas Aproximadas')
plt.show()
# Out:
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\3859091835.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=media_tempo_por_dispositivo, x='Device', y='ScreenTimeNum', palette='coolwarm')

# %%
# Tempo médio por atividade
media_tempo_por_atividade = df.groupby('Screen Activity')['ScreenTimeNum'].mean().reset_index()
px.bar(media_tempo_por_atividade, x='Screen Activity', y='ScreenTimeNum', title='Tempo de Tela por Tipo de Atividade')

# %%
# 🔍 6. Cross insights
# ScreenTime por faixa etária e produtividade
sns.barplot(data=df, x='Age Group', y='ScreenTimeNum', hue='Productivity', errorbar=None)
plt.title('Tempo Médio de Tela por Faixa Etária e Produtividade')

# Mover a legenda para fora
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()  # Para ajustar o layout e evitar cortes
plt.show()

# %%
# Notificações x Estratégia de Trabalho
sns.countplot(data=df, x='Work Strategy', hue='Notification Handling')
plt.title('Estratégia de Trabalho vs. Manuseio de Notificações')
plt.xticks(rotation=20)
plt.show()

# %%
# 📌 7. Insights rápidos
print("🔹 Faixa etária com maior tempo médio de tela:", df.groupby('Age Group')['ScreenTimeNum'].mean().idxmax())
print("🔹 Tipo de atividade mais comum:", df['Screen Activity'].mode()[0])
print("🔹 Estratégia de trabalho mais usada:", df['Work Strategy'].mode()[0])
# Out:
# 🔹 Faixa etária com maior tempo médio de tela: 25–34
# 🔹 Tipo de atividade mais comum: Entertainment (gaming, streaming, social media, etc.)
# 🔹 Estratégia de trabalho mais usada: None, i prefer to work without any strategies

# %%
df.head(5)
# Out:
#       Age Group  Gender Education Level    Occupation Average Screen Time  \
# 0         18–24    Male   Undergraduate       Student        More than 10
# 1         18–24    Male   Undergraduate  Professional                8-10
# 2  45 and above  Female        Graduate  Professional                 4–6
# 3         25–34    Male   Undergraduate  Professional                8-10
# 4  45 and above    Male        Graduate  Professional                8-10
#
#        Device                                    Screen Activity  \
# 0  Smartphone  Entertainment (gaming, streaming, social media...
# 1  Smartphone  Entertainment (gaming, streaming, social media...
# 2  Smartphone                              Academic/Work-related
# 3   Laptop/PC                              Academic/Work-related
# 4   Laptop/PC                              Academic/Work-related
#
#                                         App Category       Screen Time Period  \
# ...

# %%
# Média do valor por categoria
print(df.groupby('Education Level')['ScreenTimeNum'].mean())
# Out:
# Education Level
# Graduate                8.347826
# High school or below    7.146341
# Undergraduate           7.466667
# Name: ScreenTimeNum, dtype: float64

# %%
# Converter categorias em números (Label Encoding)
df['CategoriaCodificada'] = df['Age Group'].astype('category').cat.codes

# Correlação entre a categoria codificada e o valor
correlacao = df['CategoriaCodificada'].corr(df['ScreenTimeNum'])
print(f'Correlação: {correlacao:.2f}')
# Out:
# Correlação: -0.17

# %%
df.head()
# Out:
#       Age Group  Gender Education Level    Occupation Average Screen Time  \
# 0         18–24    Male   Undergraduate       Student        More than 10
# 1         18–24    Male   Undergraduate  Professional                8-10
# 2  45 and above  Female        Graduate  Professional                 4–6
# 3         25–34    Male   Undergraduate  Professional                8-10
# 4  45 and above    Male        Graduate  Professional                8-10
#
#        Device                                    Screen Activity  \
# 0  Smartphone  Entertainment (gaming, streaming, social media...
# 1  Smartphone  Entertainment (gaming, streaming, social media...
# 2  Smartphone                              Academic/Work-related
# 3   Laptop/PC                              Academic/Work-related
# 4   Laptop/PC                              Academic/Work-related
#
#                                         App Category       Screen Time Period  \
# ...

# %%
import pandas as pd

# Função robusta
def extrair_idades(faixa):
    faixa = faixa.strip().replace('–', '-').replace('−', '-')  # padroniza traços e remove espaços
    faixa_lower = faixa.lower()

    if 'more than' in faixa_lower:
        idade_min = int(faixa_lower.split()[-1])
        idade_max = idade_min + 2  # estimativa
    elif 'less than' in faixa_lower:
        idade_max = int(faixa_lower.split()[-1])
        idade_min = max(idade_max - 2, 0)  # não deixar negativo
    else:
        idade_min, idade_max = map(int, faixa.split('-'))

    return pd.Series([idade_min, idade_max])

# Aplicar a função
df[['screen_min', 'screen_max']] = df['Average Screen Time'].apply(extrair_idades)

# Calcular a média da faixa
df['screen_avg'] = (df['screen_min'] + df['screen_max']) / 2

# Média geral
media_geral = df['screen_avg'].mean()
print(media_geral)
# Out:
# 7.08

# %%
df['screen_avg']
# Out:
# 0      11.0
# 1       9.0
# 2       5.0
# 3       9.0
# 4       9.0
#        ...
# 195     7.0
# 196     5.0
# 197    11.0
# 198     9.0
# 199     7.0
# Name: screen_avg, Length: 200, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Corrigir valores ausentes
df.fillna("Não informado", inplace=True)

# Tabela cruzada entre tempo de tela e produtividade
cross_tab = pd.crosstab(df["Average Screen Time"], df["Productivity"], normalize='index') * 100
cross_tab = cross_tab.round(2)

# Reordenar colunas se necessário
cols_order = [
    "Extremely productive, i efficiently complete my tasks",
    "Moderately productive",
    "Unproductive, i might not have completed the task and got carried away"
]
cross_tab = cross_tab[cols_order]

# Printar a tabela formatada como no exemplo
print("\n🧠 Como interpretar os dados:")
print("Tempo de Tela (h/dia)\tExtremamente Produtivo\tModeradamente Produtivo\tPouco Produtivo")
for idx, row in cross_tab.iterrows():
    print(f"{idx}\t{row[0]:.2f}%\t\t\t{row[1]:.2f}%\t\t\t{row[2]:.2f}%")

# Gráfico de barras empilhadas
cross_tab.plot(kind='bar', stacked=True, colormap='viridis', figsize=(10, 6))
plt.title("Produtividade Relativa por Tempo Médio de Tela")
plt.xlabel("Tempo Médio de Tela (h/dia)")
plt.ylabel("Distribuição de Produtividade (%)")
plt.legend(title="Produtividade")
plt.tight_layout()
plt.show()
# Out:
# 🧠 Como interpretar os dados:
# Tempo de Tela (h/dia)	Extremamente Produtivo	Moderadamente Produtivo	Pouco Produtivo
# 2–4	31.82%			54.55%			13.64%
# 4–6	23.53%			54.90%			21.57%
# 6–8	23.53%			58.82%			17.65%
# 8-10	29.55%			50.00%			20.45%
# Less than 2	0.00%			100.00%			0.00%
# More than 10	35.48%			45.16%			19.35%
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\3858035831.py:6: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Não informado' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#
# C:\Users\ferre\AppData\Local\Temp\ipykernel_6412\3858035831.py:24: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
